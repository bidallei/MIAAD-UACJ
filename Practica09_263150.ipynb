# %% [markdown]
# <a href="https://colab.research.google.com/github/bidallei/MIAAD-UACJ/blob/main/Practica09_263150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Práctica 9**
# ---
#
# Alumno: Álvaro Hernandez Jarquín<br>
# Seminario: Programación para analítica descriptiva y predictiva
# ---

# %% [markdown]
# # Objetivo
# Utilizar plt.subplots() para visualizar diferentes distribuciones generadas con NumPy y almacenadas en un DataFrame.
#
# **Instrucciones:**
# * Genera un DataFrame con Pandas que contenga 1000 valores en cuatro columnas (Normal, Uniforme, Exponencial, Poisson).
# * Crea una figura con plt.subplots(2, 2) para organizar los histogramas en una cuadrícula de 2x2.
# * Grafica cada distribución en un subplot usando ax[i, j].hist().
# * Agrega títulos a cada subplot y ajusta la disposición con tight_layout().

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Genera un DataFrame con Pandas que contenga 1000 valores en cuatro columnas (Normal, Uniforme, Exponencial, Poisson).
df = pd.DataFrame({
    'Normal': np.random.randn(1000),
    'Uniforme': np.random.uniform(-2, 2, 1000),
    'Exponencial': np.random.exponential(1, 1000),
    'Poisson': np.random.poisson(3, 1000)
})

# Crea una figura con plt.subplots(2, 2) para organizar los histogramas en una cuadrícula de 2x2.
fig, ax = plt.subplots(2, 2, figsize=(10, 6))

# Grafica cada distribución en un subplot usando ax[i, j].hist().
ax[0, 0].hist(df['Normal'], bins=30, color="#FF4500")
ax[0, 1].hist(df['Uniforme'], bins=30, color="#FF8C00")
ax[1, 0].hist(df['Exponencial'], bins=30, color="#FFD700")
ax[1, 1].hist(df['Poisson'], bins=30, color="#FF6B6B")

# Agrega títulos a cada subplot y ajusta la disposición con tight_layout().
fig.suptitle('Distribuciones de Probabilidad', fontsize=16)
ax[0, 0].set_title("Distribución Normal")
ax[0, 1].set_title("Distribución Uniforme")
ax[1, 0].set_title("Distribución Exponencial")
ax[1, 1].set_title("Distribución de Poisson")

plt.tight_layout()
plt.show()
