# %% [markdown]
# <a href="https://colab.research.google.com/github/bidallei/MIAAD-UACJ/blob/main/ExpresionesRegularesNLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio de expresiones regulares en PLN**

# %% [markdown]
# * Asignatura: Procesamiento del Lenguaje Natural
# * Profesor: Dr. Rogelio Florencia Juárez
# * Alumno: **Álvaro Hernández Jarquín**
# * Matrícula: 263150
# *  de febrero de 2026

# %% [markdown]
# **Actividad:** Trabajando en la nube con Google Colab o localmente en tu equipo de cómputo, considera los siguientes párrafos y crea en un código de programación en Python las expresiones regulares adecuadas para las siguientes actividades. <br> Identifica en tu código el número de la actividad desarrollada. No olvides instalar las librerías adecuadas (en caso de ser necesario).

# %% [markdown]
# El 10 de agosto de 2025, María Pérez envió un correo electrónico a la dirección maria.perez@email.com solicitando información sobre el producto X-200. Su número de teléfono es +34 612-345-678. Además, visitó la web https://www.ejemplo.com para consultar precios y disponibilidad.<br>
# El servidor registró el acceso desde la IP 192.168.1.15 a las 14:23:56, y se detectó un error en el log con código ERR500. En Twitter, el usuario @DataAnalyst comentó: "Los modelos de IA son el futuro #MachineLearning #IA2025". El totaal de la compra fue de $199.99, y el cliente pagó con tarjeta VISA terminada en 1234.<br>
# Por otro lado, el DNI de Juan García es 12345678Z y su código postal 28080. Para más información, puede llamar al 911 234 567 o visitar www.informacion.es. Recordamos que las feechas límite para inscripción son 2025-09-30 y 2025-10-15.

# %%
import re

# %%
texto = """
El 10 de agosto de 2025, María Pérez envió un correo electrónico a la dirección maria.perez@email.com solicitando información sobre el producto X-200. Su número de teléfono es +34 612-345-678. Además, visitó la web https://www.ejemplo.com para consultar precios y disponibilidad.
El servidor registró el acceso desde la IP 192.168.1.15 a las 14:23:56, y se detectó un error en el log con código ERR500. En Twitter, el usuario @DataAnalyst comentó: "Los modelos de IA son el futuro #MachineLearning #IA2025". El totaal de la compra fue de $199.99, y el cliente pagó con tarjeta VISA terminada en 1234.
Por otro lado, el DNI de Juan García es 12345678Z y su código postal 28080. Para más información, puede llamar al 911 234 567 o visitar www.informacion.es. Recordamos que las feechas límite para inscripción son 2025-09-30 y 2025-10-15.
"""

# %% [markdown]
# ## 1.	Extraer todas las direcciones de correo electrónico.

# %%
consulta_uno = re.findall(r'[\w\.-]+@[\w\.-]+\.[a-z]{2,3}', texto)
print(consulta_uno)
# Out:
# ['maria.perez@email.com']

# %% [markdown]
# ## 2.	Extraer todas las URLs (con o sin protocolo).

# %%
consulta_dos = re.findall(r'(?:https?://)?www\.[\w\.-]+\.\w+(?:/[\w\./-]*)?', texto)
print(consulta_dos)
# Out:
# ['https://www.ejemplo.com', 'www.informacion.es']

# %% [markdown]
# ## 3.	Validar y extraer números de teléfono en formato internacional y nacional.

# %%
consulta_tres = re.findall(r'(?:\+\d{1,3}[ -])?\d{3}(?:[ -]\d{3}){2}', texto)
print(consulta_tres)
# Out:
# ['+34 612-345-678', '911 234 567']

# %% [markdown]
# ## 4.	Extraer fechas en formato yyyy-MM-dd.

# %%
consulta_cuatro = re.findall(r'\d{4}(?:-\d{2}){2}', texto)
print(consulta_cuatro)
# Out:
# ['2025-09-30', '2025-10-15']

# %% [markdown]
# ## 5.	Extraer códigos postales de 5 dígitos.

# %%
consulta_cinco = re.findall(r'\b\d{5}\b', texto)
print(consulta_cinco)
# Out:
# ['28080']

# %% [markdown]
# ## 6.	Extraer DNI (8 dígitos seguidos de letra mayúscula).

# %%
consulta_seis = re.findall(r'\d{8}[A-Z]', texto)
print(consulta_seis)
# Out:
# ['12345678Z']

# %% [markdown]
# ## 7.	Extraer menciones de Twitter.

# %%
consulta_siete = re.findall(r'(?<=\s)@\w+', texto)
print(consulta_siete)
# Out:
# ['@DataAnalyst']

# %% [markdown]
# ## 8.	Extraer hashtags.

# %%
consulta_ocho = re.findall(r'#\w+', texto)
print(consulta_ocho)
# Out:
# ['#MachineLearning', '#IA2025']

# %% [markdown]
# ## 9.	Extraer direcciones IP.

# %%
consulta_nueve = re.findall(r'\b(?:\d{1,3}\.){3}\d{1,3}\b', texto)
print(consulta_nueve)
# Out:
# ['192.168.1.15']

# %% [markdown]
# ## 10.	Extraer importes monetarios (con $ y decimales).

# %%
consulta_diez = re.findall(r'\$\d+\.\d{2}', texto)
print(consulta_diez)
# Out:
# ['$199.99']

# %% [markdown]
# ## 11.	Eliminar letras repetidas.

# %%
consulta_once = re.sub(r'([a-zA-Z])\1+', r'\1', texto)
print(consulta_once)
# Out:
# El 10 de agosto de 2025, María Pérez envió un coreo electrónico a la direción maria.perez@email.com solicitando información sobre el producto X-200. Su número de teléfono es +34 612-345-678. Además, visitó la web htps://w.ejemplo.com para consultar precios y disponibilidad.
# El servidor registró el aceso desde la IP 192.168.1.15 a las 14:23:56, y se detectó un eror en el log con código ER500. En Twiter, el usuario @DataAnalyst comentó: "Los modelos de IA son el futuro #MachineLearning #IA2025". El total de la compra fue de $199.99, y el cliente pagó con tarjeta VISA terminada en 1234.
# Por otro lado, el DNI de Juan García es 12345678Z y su código postal 28080. Para más información, puede lamar al 911 234 567 o visitar w.informacion.es. Recordamos que las fechas límite para inscripción son 2025-09-30 y 2025-10-15.

# %% [markdown]
# P.D. En caso de que debamos identificar primero las letras que corresponden a letras de palabras que son correctas duplicadas (p. ej. "dirección"), primero ejecutamos una consulta para identificarlas y luego las eliminamos de la consulta

# %%
consulta_doce = re.findall(r'(([a-zA-Z])\2+)', texto)
print(consulta_doce)
# Out:
# [('rr', 'r'), ('cc', 'c'), ('tt', 't'), ('www', 'w'), ('cc', 'c'), ('rr', 'r'), ('RR', 'R'), ('tt', 't'), ('aa', 'a'), ('ll', 'l'), ('www', 'w'), ('ee', 'e')]

# %%
consulta_once_cambiada = re.sub(r'(([abd-km-np-qs-tv-z])\2+)', r'\2', texto, flags=re.IGNORECASE)
print(consulta_once_cambiada)
# Out:
# El 10 de agosto de 2025, María Pérez envió un correo electrónico a la dirección maria.perez@email.com solicitando información sobre el producto X-200. Su número de teléfono es +34 612-345-678. Además, visitó la web htps://w.ejemplo.com para consultar precios y disponibilidad.
# El servidor registró el acceso desde la IP 192.168.1.15 a las 14:23:56, y se detectó un error en el log con código ERR500. En Twiter, el usuario @Datanalyst comentó: "Los modelos de IA son el futuro #MachineLearning #IA2025". El total de la compra fue de $199.99, y el cliente pagó con tarjeta VISA terminada en 1234.
# Por otro lado, el DNI de Juan García es 12345678Z y su código postal 28080. Para más información, puede llamar al 911 234 567 o visitar w.informacion.es. Recordamos que las fechas límite para inscripción son 2025-09-30 y 2025-10-15.
